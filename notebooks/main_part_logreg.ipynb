# %% [markdown]
# # Анализ тональности твитов о коронавирусе
# ***В период пандемии COVID-19 социальные сети стали основным каналом для выражения эмоций. Анализ тональности (sentiment analysis) твитов в подобные кризисные периоды позволяет отслеживать общественные настроения и выявлять тревожные тенденции у населения.***
#
# **Цель**: построить классификатор, который по тексту твита определяет его эмоциональную окраску (положительную или отрицательную). Для этого я использовала классические методы NLP: токенизацию, удаление стоп-слов, стемминг, векторизацию с помощью Bag-of-Words и TF-IDF, а также логистическую регрессию в качестве модели.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, confusion_matrix, ConfusionMatrixDisplay, classification_report
from sklearn.preprocessing import MaxAbsScaler
from sklearn.dummy import DummyClassifier
from wordcloud import WordCloud
import pickle
import warnings
warnings.filterwarnings('ignore')

# %%
import sys
import os
current_dir = os.getcwd()
project_root = os.path.abspath(os.path.join(current_dir, '..'))
sys.path.insert(0, project_root)

from src.tokenizers import custom_tokenizer, custom_stem_tokenizer
from src.model_eval import evaluate_model
from src.final_tokenizer import custom_new_tokenizer

# %% [markdown]
# # Предобработка данных

# %%
df = pd.read_csv('../data/tweets_coronavirus.csv', encoding='latin-1')
df.head()
# Out:
#    UserName  ScreenName                     Location     TweetAt  \
# 0      3800       48752                           UK  16-03-2020
# 1      3801       48753                    Vagabonds  16-03-2020
# 2      3802       48754                          NaN  16-03-2020
# 3      3803       48755                          NaN  16-03-2020
# 4      3804       48756  ÃÂT: 36.319708,-82.363649  16-03-2020
#
#                                        OriginalTweet           Sentiment
# 0  advice Talk to your neighbours family to excha...            Positive
# 1  Coronavirus Australia: Woolworths to give elde...            Positive
# 2  My food stock is not the only one which is emp...            Positive
# 3  Me, ready to go at supermarket during the #COV...  Extremely Negative
# 4  As news of the regionÃÂs first confirmed COV...            Positive

# %%
df['Binary_sentiment'] = df['Sentiment'].apply(lambda x: 1 if x in ['Positive', 'Extremely Positive'] else 0)

# %%
X = df['OriginalTweet']
y = df['Binary_sentiment']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0, stratify=y)

# %% [markdown]
# # Векторизация текстов

# %% [markdown]
# ## CountVectorizer

# %%
cv = CountVectorizer(tokenizer=custom_tokenizer)
cv.fit(X_train)
print(f'Размер словаря: {len(cv.vocabulary_)}')
# Out:
# Размер словаря: 45083

# %% [markdown]
# Рассмотрим какой-нибудь конкретный твит и определим в нем наиболее и наименее важные токены

# %%
ind = 9023
tw_text = df.iloc[ind]['OriginalTweet']
tw_sentiment = df.iloc[ind]['Sentiment']
print(tw_text)
print(f'Sentiment: {tw_sentiment}')
# Out:
# Shop keepers taking advantage of #Coronavirus boosting prices disproportionately so the most Marginalised suffer who can't afford it #SHAMEONYOU #Wewillremember
# Sentiment: Negative

# %%
tw_vector = cv.transform([tw_text])
feature_names = cv.get_feature_names_out()
tw_array = tw_vector.toarray()[0]
non_zero_ind = np.where(tw_array > 0)[0]

max_index = non_zero_ind[np.argmax(tw_array[non_zero_ind])]
min_index = non_zero_ind[np.argmin(tw_array[non_zero_ind])]
print(f"Наиболее важный токен: '{feature_names[max_index]}' — {tw_array[max_index]}")
print(f"Наименее важный токен: '{feature_names[min_index]}' — {tw_array[min_index]}")
# Out:
# Наиболее важный токен: '#coronavirus' — 1
# Наименее важный токен: '#coronavirus' — 1

# %% [markdown]
# Cамый важный и самый неважный токены (компоненты которых в векторе максимальны/минимальны, без учета нулевых) совпадают, потому что каждый токен в твите встречается по одному разу (у всех токенов одинаковая частота 1), и argmax с argmin берут первый попавшийся токен. Это значит, **CountVectorizer плохо подходит для классификации**, так как определяет важность только по частоте в одном твите

# %% [markdown]
# ## TfidfVectorizer

# %%
tfidf = TfidfVectorizer(tokenizer=custom_tokenizer)
tfidf.fit(X_train)
# Out:
# TfidfVectorizer(tokenizer=<function custom_tokenizer at 0x000001CEAE5B1010>)

# %%
tw_vector_tfidf = tfidf.transform([tw_text])
feature_names_tfidf = tfidf.get_feature_names_out()
tweet_array_tfidf = tw_vector_tfidf.toarray()[0]
non_zero_tfidf = np.where(tweet_array_tfidf > 0)[0]
max_idx_tfidf = non_zero_tfidf[np.argmax(tweet_array_tfidf[non_zero_tfidf])]
min_idx_tfidf = non_zero_tfidf[np.argmin(tweet_array_tfidf[non_zero_tfidf])]
    
print(f"Наиболее важный токен: '{feature_names_tfidf[max_idx_tfidf]}' — {tweet_array_tfidf[max_idx_tfidf]:.4f}")
print(f"Наименее важный токен: '{feature_names_tfidf[min_idx_tfidf]}' — {tweet_array_tfidf[min_idx_tfidf]:.4f}")
# Out:
# Наиболее важный токен: '#wewillremember' — 0.3760
# Наименее важный токен: '#coronavirus' — 0.0720

# %% [markdown]
# \#wewillremember - редкий хештег во всем корпусе, поэтому получил высокий вес (0,376), а #coronavirus - очень частый хештег среди всех твитов, получил низкий вес (0,072). Можно сделать вывод, что **TF-IDF лучше подходит для классификации**, потому что выделяет редкие информативные токены и игнорирует общие слова

# %% [markdown]
# Проверим, как работает TfidfVectorizer, на каком-нибудь положительном твите

# %%
pos_ind = 43
pos_tweet = df.iloc[pos_ind]['OriginalTweet']
print(pos_tweet)
print(f'Sentiment: {df.iloc[pos_ind]['Sentiment']}')
# Out:
# Morning everyone have a great and safe day. ??? #coronavirus #StopPanicBuying #BeKind #mufc #MUFC_Family
# Sentiment: Extremely Positive

# %%
tw_vector_tfidf = tfidf.transform([pos_tweet])
feature_names_tfidf = tfidf.get_feature_names_out()
tweet_array_tfidf = tw_vector_tfidf.toarray()[0]
non_zero_tfidf = np.where(tweet_array_tfidf > 0)[0]
max_idx_tfidf = non_zero_tfidf[np.argmax(tweet_array_tfidf[non_zero_tfidf])]
min_idx_tfidf = non_zero_tfidf[np.argmin(tweet_array_tfidf[non_zero_tfidf])]
    
print(f"Наиболее важный токен: '{feature_names_tfidf[max_idx_tfidf]}' — {tweet_array_tfidf[max_idx_tfidf]:.4f}")
print(f"Наименее важный токен: '{feature_names_tfidf[min_idx_tfidf]}' — {tweet_array_tfidf[min_idx_tfidf]:.4f}")
# Out:
# Наиболее важный токен: '#bekind' — 0.5091
# Наименее важный токен: '#coronavirus' — 0.1346

# %% [markdown]
# На примере нашего резко положительного твита TfidfVectorizer хорошо выделяет важные токены: #bekind - редкий хештег, несет прямую положительную эмоциональную окраску, TF-IDF правильно определил ему большой вес (0.5)

# %% [markdown]
# # Обучение первых моделей

# %% [markdown]
# ## Наивный классификатор
# До обучения сложных моделей оценим, какую точность даёт самый простой подход — предсказание самого частого класса.

# %%
dummy = DummyClassifier(strategy="most_frequent")
dummy.fit(X_train, y_train)
y_pred_dummy = dummy.predict(X_test)
dummy_accuracy = accuracy_score(y_test, y_pred_dummy)
print(f"Accuracy DummyClassifier: {dummy_accuracy:.4f}")
# Out:
# Accuracy DummyClassifier: 0.5396

# %% [markdown]
# ## Логистическая регрессия

# %% [markdown]
# Сравним CountVectorizer и TfidfVectorizer, обучив логистическую регрессию на векторах из обоих векторайзеров

# %%
X_train_cv = cv.transform(X_train)
X_test_cv = cv.transform(X_test)

X_train_tfidf = tfidf.transform(X_train)
X_test_tfidf = tfidf.transform(X_test)

# %%
metrics_cv = evaluate_model(LogisticRegression(max_iter=1000, random_state=0), X_train_cv, y_train, X_test_cv, y_test, model_name='CV')
metrics_tfidf = evaluate_model(LogisticRegression(max_iter=1000, random_state=0), X_train_tfidf, y_train, X_test_tfidf, y_test, model_name='Tfidf')
results = [metrics_cv, metrics_tfidf]
first_df = pd.DataFrame(results).round(4)
first_df
# Out:
#    Model  Train Accuracy  Test Accuracy  Test ROC-AUC  Overfit
# 0     CV          0.9837         0.8731        0.9402   0.1106
# 1  Tfidf          0.9251         0.8513        0.9292   0.0738

# %% [markdown]
# Обе модели показали высокие результаты на тесте (Accuracy > 85%). CountVectorizer показал более высокую точность на тесте, но при этом большое переобучение (разрыв между train и test 11%), а TF-IDF показал меньшее переобучение, но ниже точность на тесте. То есть TF-IDF будет лучше работать на новых данных

# %% [markdown]
# ## Облако слов

# %%
train_indices = X_train.index
train_df = df.loc[train_indices]

positive_tweets = train_df[train_df['Binary_sentiment'] == 1]['OriginalTweet']
positive_tokens = []
for tweet in positive_tweets:
    positive_tokens.extend(custom_tokenizer(tweet))

negative_tweets = train_df[train_df['Binary_sentiment'] == 0]['OriginalTweet']
negative_tokens = []
for tweet in negative_tweets:
    negative_tokens.extend(custom_tokenizer(tweet))

# %%
wc_neg = WordCloud(width=800, height=400, max_words=125, normalize_plurals=False, colormap='Reds', 
                   random_state=0).generate(' '.join(negative_tokens))
wc_pos = WordCloud(width=800, height=400, max_words=125, normalize_plurals=False, colormap='Greens', 
                   random_state=0).generate(' '.join(positive_tokens))

plt.style.use('dark_background')
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 8))

ax1.imshow(wc_neg, interpolation='bilinear')
ax1.set_title('Отрицательные твиты', fontsize=18)
ax1.axis('off')

ax2.imshow(wc_pos, interpolation='bilinear')
ax2.set_title('Положительные твиты', fontsize=18)
ax2.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# Проверим с помощью облаков слов, какие слова видит наша текущая модель для каждого класса. Самые крупные слова (то есть самые частотные) примерно **одинаковы для обоих классов**: это слова и сочетания, соответствующие теме твитов *(coronavirus, covid, supermarket, grocery store, people)* и при этом эмоционально не окрашены (их можно убрать).
#
# Среди менее частотных слов уже заметны слова, которые по эмоциональной окраске относятся только к одному классу:
# - *Panic buying, covid crisis, risk, fear* - эти и некоторые другие негативно окрашенные слова встречаются в отрицательных твитах,
# - *Good, thank, support, safe* - примеры слов из положительных твитов.

# %% [markdown]
# # Улучшение качества моделей

# %% [markdown]
# ## Стемминг

# %% [markdown]
# Используем модифицированную версию токенайзера с добавленным стеммингом

# %%
cv_stem = CountVectorizer(tokenizer=custom_stem_tokenizer)
X_train_cv_stem = cv_stem.fit_transform(X_train)

print(f'Размер словаря после стемминга: {len(cv_stem.vocabulary_)}')
# Out:
# Размер словаря после стемминга: 36369

# %% [markdown]
# Размер словаря уменьшился с 45083 до 36369, потому что при стемминге у слов отбрасываются суффиксы и окончания, что помогает сократить количество уникальных токенов без потери смысла

# %%
X_test_cv_stem = cv_stem.transform(X_test)

tfidf_stem = TfidfVectorizer(tokenizer=custom_stem_tokenizer)
X_train_tfidf_stem = tfidf_stem.fit_transform(X_train)
X_test_tfidf_stem = tfidf_stem.transform(X_test)

# %%
metrics_cv_stem = evaluate_model(LogisticRegression(max_iter=1000, random_state=0), X_train_cv_stem, y_train, X_test_cv_stem, y_test, model_name='CV stemming')
metrics_tfidf_stem = evaluate_model(LogisticRegression(max_iter=1000, random_state=0), X_train_tfidf_stem, y_train, X_test_tfidf_stem, y_test, model_name='Tfidf stemming')
results.append(metrics_cv_stem)
results.append(metrics_tfidf_stem)

# %%
stem_df = pd.DataFrame(results).round(4)
stem_df.sort_values('Model')
# Out:
#             Model  Train Accuracy  Test Accuracy  Test ROC-AUC  Overfit
# 0              CV          0.9837         0.8731        0.9402   0.1106
# 2     CV stemming          0.9707         0.8708        0.9376   0.0999
# 1           Tfidf          0.9251         0.8513        0.9292   0.0738
# 3  Tfidf stemming          0.9170         0.8599        0.9315   0.0571

# %% [markdown]
# Для оценки качества моделей были использованы `Accuracy` (долю правильных ответов) и `ROC-AUC` (способность модели различать классы). F1-Score не рассматривался отдельно, так как классы сбалансированы (54% / 46%), и в таких условиях F1 практически совпадает с Accuracy, не добавляя новой информации.
#
# - Лучшей моделью по обоим метрикам на тесте оказался **CountVectorizer без стемминга** (accuracy = 0.87, ROC-AUC = 0.94). Однако она показывает наибольшее переобучение (разрыв Train-Test на Accuracy = 11%).
# - Модель с лучшим балансом качества и обобщения - это **TF-IDF со стеммингом** (accuracy 0.86, ROC-AUC 0.93, разрыв Train-Test всего 5.7%). Модель хорошо работает на новых данных и меньше всего подвержена переобучению, имеет смысл оптимизировать ее дальше

# %% [markdown]
# ## Биграммы

# %%
tfidf2_stem = TfidfVectorizer(tokenizer=custom_stem_tokenizer, ngram_range=(1,2))
X_train_tfidf2_stem = tfidf2_stem.fit_transform(X_train)
X_test_tfidf2_stem = tfidf2_stem.transform(X_test)

# %%
metrics_tf_bi = evaluate_model(LogisticRegression(max_iter=1000, random_state=0), X_train_tfidf2_stem, y_train, X_test_tfidf2_stem, y_test, model_name='Tfidf stem bi')
bi_df = pd.concat([stem_df[stem_df['Model'] == 'Tfidf stemming'], pd.DataFrame([metrics_tf_bi])], ignore_index=True)
bi_df.round(4)
# Out:
#             Model  Train Accuracy  Test Accuracy  Test ROC-AUC  Overfit
# 0  Tfidf stemming          0.9170         0.8599        0.9315   0.0571
# 1   Tfidf stem bi          0.9475         0.8425        0.9148   0.1050

# %% [markdown]
# Использование биграммов на лучшей модели (TF-IDF со стеммингом) **ухудшило качество предсказания**:
# - Accuracy и ROC-AUC на тесте понизились, по сравнению с моделью, обученной на униграммах,
# - Переобучение выросло в два раза (разрыв Train-Test вырос с 5% до 10%).
#
# Так как твиты довольно короткие (в среднем 213 символов), биграммы повторяются крайне редко. Это создает шум, на который модель и переобучается. В нашем случае лучше ограничиться униграммами, так как использование больших N-граммов приведет только к более сильному переобучению.

# %% [markdown]
# ## Работа с частотами

# %% [markdown]
# Чтобы улучшить нашу модель попробуем настроить гиперпараметры, отвечающие за частоту документа:
# - `min_df` - минимальная частота документа (удаляет редкие слова),
# - `max_df` - максимальная частота документа (удаляет слишком частые слова)

# %%
pipeline = Pipeline([
    ('tfidf', TfidfVectorizer(tokenizer=custom_stem_tokenizer)),
    ('logreg', LogisticRegression(max_iter=1000, random_state=0))
])

# %%
param_grid = {
    'tfidf__min_df': [1, 3, 5, 10],
    'tfidf__max_df': [0.5, 0.7, 0.9, 1]
    }
grid = GridSearchCV(pipeline, param_grid, cv=3, scoring='accuracy')
grid.fit(X_train, y_train)
print(f'Лучшие параметры: {grid.best_params_}')
print(f'Лучший Accuracy на кросс-валидации: {grid.best_score_:.4f}')
# Out:
# Лучшие параметры: {'tfidf__max_df': 0.5, 'tfidf__min_df': 5}
# Лучший Accuracy на кросс-валидации: 0.8436

# %%
tf = TfidfVectorizer(tokenizer=custom_stem_tokenizer, min_df=5, max_df=0.5).fit(X_train)
print(f'Размер нового словаря: {len(tf.vocabulary_)}')
# Out:
# Размер нового словаря: 6121

# %% [markdown]
# - `min_df=5`: удалены токены, встречающиеся менее чем в 5 твитах. Это отсеяло редкие опечатки, уникальные ссылки и имена, которые создавали шум.
# - `max_df=0.5`: удалены токены, встречающиеся более чем в 50% твитов. Это удалило слишком общие слова, которые не несли тональности и создавали переобучение.
#
# **Результат:** Размер словаря сократился с 36369 до 6121 токенов. Это значит, что большинство уникальных токенов в твитах встречаются лишь 1–2 раза и являются шумом (опечатки, уникальные ссылки, имена)

# %%
tf_tuned = TfidfVectorizer(tokenizer=custom_stem_tokenizer, min_df=5, max_df=0.5)
X_train_tuned = tf_tuned.fit_transform(X_train)
X_test_tuned = tf_tuned.transform(X_test)

# %%
lr = LogisticRegression(max_iter=1000, random_state=0)
lr.fit(X_train_tuned, y_train)
metrics_tf = evaluate_model(lr, X_train_tuned, y_train, X_test_tuned, y_test, model_name='Tfidf stem tuned', fitted=True)

# %%
tuned_df = pd.concat([stem_df[stem_df['Model'] == 'Tfidf'], stem_df[stem_df['Model'] == 'Tfidf stemming'], 
                      pd.DataFrame([metrics_tf])], ignore_index=True)
tuned_df.round(4)
# Out:
#               Model  Train Accuracy  Test Accuracy  Test ROC-AUC  Overfit
# 0             Tfidf          0.9251         0.8513        0.9292   0.0738
# 1    Tfidf stemming          0.9170         0.8599        0.9315   0.0571
# 2  Tfidf stem tuned          0.9052         0.8641        0.9340   0.0411

# %% [markdown]
# Подбор гиперпараметров помог повысить качество предсказаний:
# - Accuracy и ROC-AUC на тесте немного выросли,
# - Уменьшилось переобучение, так как удаление редких и частых токенов заставило модель фокусироваться на действительно значимых повторяющихся паттернах.

# %% [markdown]
# ## Масштабирование

# %% [markdown]
# Используем `MaxAbsScaler` для масштабирования данных, так как он лучше всего работает с разреженными матрицами

# %%
scaler = MaxAbsScaler() 
X_train_scaled = scaler.fit_transform(X_train_tuned)
X_test_scaled = scaler.transform(X_test_tuned)

lr_scaled = LogisticRegression(max_iter=1000, random_state=0)
metrics_sc = evaluate_model(lr_scaled, X_train_scaled, y_train, X_test_scaled, y_test, model_name='Tfidf stem tuned scaled')

# %%
scaled_df = pd.concat([tuned_df, pd.DataFrame([metrics_sc])], ignore_index=True)
scaled_df.style.highlight_max(subset=['Test Accuracy'], color='green')
# Out:
# <style type="text/css">
# #T_7c048_row2_col2 {
#   background-color: green;
# }
# </style>
# <table id="T_7c048">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c048_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7c048_level0_col1" class="col_heading level0 col1" >Train Accuracy</th>
#       <th id="T_7c048_level0_col2" class="col_heading level0 col2" >Test Accuracy</th>
#       <th id="T_7c048_level0_col3" class="col_heading level0 col3" >Test ROC-AUC</th>
#       <th id="T_7c048_level0_col4" class="col_heading level0 col4" >Overfit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c048_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7c048_row0_col0" class="data row0 col0" >Tfidf</td>
#       <td id="T_7c048_row0_col1" class="data row0 col1" >0.925100</td>
#       <td id="T_7c048_row0_col2" class="data row0 col2" >0.851300</td>
#       <td id="T_7c048_row0_col3" class="data row0 col3" >0.929200</td>
#       <td id="T_7c048_row0_col4" class="data row0 col4" >0.073800</td>
#     </tr>
#     <tr>
#       <th id="T_7c048_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7c048_row1_col0" class="data row1 col0" >Tfidf stemming</td>
#       <td id="T_7c048_row1_col1" class="data row1 col1" >0.917000</td>
#       <td id="T_7c048_row1_col2" class="data row1 col2" >0.859900</td>
#       <td id="T_7c048_row1_col3" class="data row1 col3" >0.931500</td>
#       <td id="T_7c048_row1_col4" class="data row1 col4" >0.057100</td>
#     </tr>
#     <tr>
#       <th id="T_7c048_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7c048_row2_col0" class="data row2 col0" >Tfidf stem tuned</td>
#       <td id="T_7c048_row2_col1" class="data row2 col1" >0.905169</td>
#       <td id="T_7c048_row2_col2" class="data row2 col2" >0.864062</td>
#       <td id="T_7c048_row2_col3" class="data row2 col3" >0.933977</td>
#       <td id="T_7c048_row2_col4" class="data row2 col4" >0.041107</td>
#     </tr>
#     <tr>
#       <th id="T_7c048_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7c048_row3_col0" class="data row3 col0" >Tfidf stem tuned scaled</td>
#       <td id="T_7c048_row3_col1" class="data row3 col1" >0.931482</td>
#       <td id="T_7c048_row3_col2" class="data row3 col2" >0.863464</td>
#       <td id="T_7c048_row3_col3" class="data row3 col3" >0.936497</td>
#       <td id="T_7c048_row3_col4" class="data row3 col4" >0.068018</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# `MaxAbsScaler` дал небольшой прирост ROC‑AUC (0.9365 против 0.9340), но при этом **ухудшил обобщение** (Overfit вырос до 0.068) и немного снизил Accuracy на тесте.
#
# Так произошло из-за того, что `TfidfVectorizer` сам нормализует признаки (длина вектора каждого документа = 1 при norm='l2', который стоит по дефолту). Дополнительное масштабирование не добавляет новой информации, а лишь меняет масштаб, что не влияет на линейные модели с правильной регуляризацией.
#
# Поэтому лучшей моделью остался **TF-IDF со стеммингом и подобранными гиперпараметрами**

# %% [markdown]
# # Настройка классификатора

# %% [markdown]
# После фиксации лучших параметров векторайзера (`min_df=5`, `max_df=0.5`) попробуем оптимизировать сам классификатор

# %%
param_grid_lr = [
    {'penalty': ['l1'],
    'solver': ['saga', 'liblinear'],
    'C': [0.01, 0.05, 0.1, 0.5, 1.0, 2.0, 5.0]},
    
    {'penalty': ['l2'],
     'solver': ['lbfgs', 'saga'],
    'C': [0.01, 0.05, 0.1, 0.5, 1.0, 2.0, 5.0]}
]

# %%
grid_lr = GridSearchCV(LogisticRegression(max_iter=1000, random_state=0), param_grid_lr, cv=4, scoring='accuracy', n_jobs=-1, verbose=1)
grid_lr.fit(X_train_tuned, y_train)
print(f"Лучшие параметры для классификатора: {grid_lr.best_params_}")
print(f"Лучший Accuracy на кросс-валидации: {grid_lr.best_score_:.4f}")
# Out:
# Fitting 4 folds for each of 28 candidates, totalling 112 fits
# Лучшие параметры для классификатора: {'C': 2.0, 'penalty': 'l1', 'solver': 'liblinear'}
# Лучший Accuracy на кросс-валидации: 0.8771

# %%
best_lr = grid_lr.best_estimator_
metrics_bp = evaluate_model(best_lr, X_train_tuned, y_train, X_test_tuned, y_test, 'Best params')
bp_df = pd.concat([tuned_df, pd.DataFrame([metrics_bp])], ignore_index=True)
bp_df.round(4)
# Out:
#               Model  Train Accuracy  Test Accuracy  Test ROC-AUC  Overfit
# 0             Tfidf          0.9251         0.8513        0.9292   0.0738
# 1    Tfidf stemming          0.9170         0.8599        0.9315   0.0571
# 2  Tfidf stem tuned          0.9052         0.8641        0.9340   0.0411
# 3       Best params          0.9231         0.8834        0.9469   0.0397

# %% [markdown]
# По результатам GridSearchCV больший прирост  Accuracy на кроссвалидации дала **L1-регуляризация** (С=2 и solver='liblinear'), которая автоматически отбирает признаки и снижает переобучение.
#
# После оценки новой модели на тестовой выборке можно заметить, что действительно **уменьшилось переобучение**, а также **выросли обе метрики** на тестовой выборке. Поэтому лучшей моделью по метрикам и балансу между качеством и обобщением стала **логистическая регрессия с L1-регуляризацией** (C=2.0, solver='liblinear'), обученная на **TfidfVectorizer со стеммингом** (min_df=5, max_df=0.5).

# %% [markdown]
# # Результаты

# %% [markdown]
# ## Важность признаков

# %%
feature_names = tf_tuned.get_feature_names_out()
coefficients = best_lr.coef_[0]

top_neg_idx = np.argsort(coefficients)[:15]
top_neg = [(feature_names[i], coefficients[i]) for i in top_neg_idx]
tokens_neg = [t[0] for t in top_neg]
weights_neg = [t[1] for t in top_neg]

top_pos_idx = np.argsort(coefficients)[-15:][::-1]
top_pos = [(feature_names[i], coefficients[i]) for i in top_pos_idx]
tokens_pos = [t[0] for t in top_pos]
weights_pos = [t[1] for t in top_pos]

plt.style.use('default')
fig, axes = plt.subplots(1, 2, figsize=(10, 5))
most_imp = np.max(np.abs(weights_neg + weights_pos))
lim = most_imp+1

axes[0].barh(tokens_neg, weights_neg, color='red')
axes[0].set_xlim(-lim, 0)
axes[0].set_title('Топ-15 токенов отрицательного класса', fontsize=14)
axes[0].set_xlabel('Коэффициент')
axes[0].invert_yaxis()

axes[1].barh(tokens_pos, weights_pos, color='green')
axes[1].set_xlim(0, lim)
axes[1].set_title('Топ-15 токенов положительного класса', fontsize=14)
axes[1].set_xlabel('Коэффициент')
axes[1].invert_yaxis()
axes[1].yaxis.tick_right()

plt.tight_layout()
plt.show()

# %% [markdown]
# В токенах из обоих топов есть явные признаки негатива и позитива, поэтому они распределены корректно. Можем заметить, что стемминг сработал правильно и в топах только корни слов, а не различные их формы. Токен с самым большим по модулю весом (crisi с весом ~-22) сильнее всего влияет на предсказание, твиты со словом crisis как раз склоняются к отрицательному классу.
#
# Единственный токен, вызывающий сомнение относительно своей эмоциональной окраски - **'da'** из топа отрицательного класса. Посмотрим в каких твитах он встречается и какую окраску они имеют

# %%
for idx, tweet in enumerate(X_train):
    tokens = custom_stem_tokenizer(tweet)
    if 'da' in tokens:
        print(idx, tweet)
# Out:
# 5095 Thanks Costco! You da best! Fuck all those ass hats that bought everything only to resale at ridiculous prices. #coronavirus #COVID19 #CoronaVirusChallenge #SocialDistanacing #StaySafeStayHome #COVID https://t.co/vq6ahKQlkt
# 9292 The ALIENS have sent the #Coronavirus to Earth for a Human Slow Death @CNBCJulianna @CNBCJou this shit is #Crazy. Grocery Store workers are dying from da RONA now. I HOPE this is Fake news as my Favorito American President states. "Only CNN would ask a question like that" #Idiot
# 9817 @Naveen_Odisha @SarangiSudhansu @narendramodi @PMOIndia sir I m a retail shop worker. I m facing lots of challenges 2 reach 2 da store every day.Neither u r supporting nor taking a strong call to close the retail shops. Why ?? We don't have family ? We ar
# 10440 REMINDER IT S ILLEGAL for a business to increase prices for essential goods services more than 10 during a declared state of emergency REPORT suspected to the DA s Consumer Protection Unit 619 531 3507 DETAILS
# 15407 Na, wer war denn da am Werk? Gestern Nachmittag konnten Anwohner*innen des Stadtteil Praunheim in Frankfurt diese Aktion bestaunen. Wer dafÃÂ¼r verantwortlich ist, ist unklar. Danke an Melanie Theiss fÃÂ¼r die Zusendung des Fotos.
#
# Bild: Elizabeth Maks https://t.co/ul10HTIO2h
# 16481 Amidst the selfish &amp; mindless panic shopping around da world resulting in worldwide shortage of food products &amp; essentials, hereÃÂs #UAE! The country has assured &amp; reassured all people of the continued availability f necessities... truly blessed nation by God! #Covid_19 https://t.co/ADTELQqbYQ
# 17247 @AmitShah @MoHFW_INDIA @Vkpandia sir I m a retail shop worker. I m facing lots of challenges 2 reach 2 da store every day.Neither u r supporting nor taking a strong call to close the retail shops. Why ?? We don't have family ? We are not prone to COVID-19
# 18544 sir I m a retail shop worker. I m facing lots of challenges 2 reach 2 da store every day.Neither u r supporting nor taking a strong call to close the retail shops. Why ?? We don't have family ? We are not prone to COVID-19 @vkpandian
# 22906 Price Gouged? The DA's Bureau of Investigation have set up a hotline to report suspected price gouging as it relates to COVID-19. You can call their Consumer Protection Price Hotline: (951) 955-0764 or fill out a complain form: https://t.co/3k6y0yvgvv
# https://t.co/JACHsL1Ola https://t.co/OPsTCzPJj8

# %%
da_pos = 0
da_neg = 0
for idx, tweet in enumerate(X_train):
    tokens = custom_stem_tokenizer(tweet)
    if 'da' in tokens:
        if y_train.iloc[idx] == 1:
            da_pos += 1
        else:
            da_neg += 1

print(f"'da' в позитивных твитах: {da_pos}")
print(f"'da' в негативных твитах: {da_neg}")
# Out:
# 'da' в позитивных твитах: 1
# 'da' в негативных твитах: 8

# %% [markdown]
# Теперь понятно, что 'da' в основном используется как сленговое сокращение от 'the', но его нет в списке стоп слов. Этот токен в 8 из 9 случаев встречается в отрицательно окрашенных твитах, поэтому модель распределила ему такой вес.
#
# Лучше **добавить это слово в стоп-слова**, потому что оно не несет прямой негативной окраски, но при этом входит в топ-10 по важности, из-за чего модель может неверно классифицировать твиты.
#
# Проверим работу модели после удаления этого слова:

# %%
tf_new = TfidfVectorizer(tokenizer=custom_new_tokenizer, min_df=5, max_df=0.5)
X_train_vect = tf_new.fit_transform(X_train)
X_test_vect = tf_new.transform(X_test)
print(f'Размер нового словаря: {len(tf_new.vocabulary_)}')
# Out:
# Размер нового словаря: 6120

# %%
best_model = LogisticRegression(max_iter=1000, penalty='l1', C=2.0, solver='liblinear', random_state=0)
metrics_da = evaluate_model(best_model, X_train_vect, y_train, X_test_vect, y_test, 'Without da')
final_df = pd.concat([bp_df, pd.DataFrame([metrics_da])], ignore_index=True)
final_df.round(5)
# Out:
#               Model  Train Accuracy  Test Accuracy  Test ROC-AUC  Overfit
# 0             Tfidf         0.92510        0.85130       0.92920  0.07380
# 1    Tfidf stemming         0.91700        0.85990       0.93150  0.05710
# 2  Tfidf stem tuned         0.90517        0.86406       0.93398  0.04111
# 3       Best params         0.92307        0.88340       0.94689  0.03967
# 4        Without da         0.92311        0.88350       0.94727  0.03961

# %% [markdown]
# По сравнению с предыдущей моделью незначительно увеличились Accuracy и ROC-AUC на тесте и немного уменьшилось пееробучение. Удаление одного токена не дало сильного прироста в качестве, но это логично с точки зрения удаления ненужных слов из словаря

# %% [markdown]
# ## Визуализация и оценка

# %%
y_test_pred = best_model.predict(X_test_vect)
y_test_proba = best_model.predict_proba(X_test_vect)[:, 1]

# %%
errors = X_test[y_test_pred != y_test]
true_labels = y_test[y_test_pred != y_test]
pred_labels = y_test_pred[y_test_pred != y_test]

print("Примеры ошибочно классифицированных твитов (настоящий класс - предсказанный класс):")
for i in range(5):
    print(f"{true_labels.iloc[i]} - {pred_labels[i]}: {errors.iloc[i]}")
# Out:
# Примеры ошибочно классифицированных твитов (настоящий класс - предсказанный класс):
# 0 - 1: With public health regulations having forced bars and restaurants across Australia to close, local distilleries have begun making hand sanitizer to meet high demand and keep staff employed during the #coronavirus pandemic.
#
# https://t.co/az4Nxgx17X
# 0 - 1: #Coronavirus is not going away that easily. Day by day the situation is getting worse.
#
# If you own a #GroceryStore or a #retail store then you can offer a #grocerydelivery app service. https://t.co/3eX9vmRDih
#
# #grocery #onlinegrocery #groceryindustry #groceries #groceryshopping
# 1 - 0: #covid19 #coronavirus
# Delivery drivers face pandemic without sick pay, insurance, sanitizer https://t.co/X7pOQCnz2X
# 0 - 1: Once rare now common I wonder what dramatic changes we will see on the other side of While walking across the parking lot before entering a local supermarket I was struck by the large number of discarded Ubiquitous shopping trash of the future
# 1 - 0: Australian prices could fall by 20 That s if the pandemic triggers a deep   and if unemployment surges past 10 Those were some of the key points from my interview w who s got an amazing home office setup btw

# %%
print(classification_report(y_test, y_test_pred, target_names=['Positive', 'Negative']))
# Out:
#               precision    recall  f1-score   support
#
#     Positive       0.88      0.86      0.87      4620
#     Negative       0.89      0.90      0.89      5414
#
#     accuracy                           0.88     10034
#    macro avg       0.88      0.88      0.88     10034
# weighted avg       0.88      0.88      0.88     10034

# %%
cm = confusion_matrix(y_test, y_test_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Negative', 'Positive'])
disp.plot(cmap='Blues')
plt.title('Матрица ошибок')
plt.show()

# %%
fpr, tpr, _ = roc_curve(y_test, y_test_proba)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'ROC-AUC = {roc_auc_score(y_test, y_test_proba):.4f}')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая для лучшей модели')
plt.legend(loc='lower right')
plt.grid(alpha=0.5)
plt.show()

# %%
with open('../models/logreg_tfidf.pkl', 'wb') as f:
    pickle.dump((tf_new, best_model), f)

# %% [markdown]
# ## Выводы
#
# ### Лучшая модель
# - Векторизатор: `TfidfVectorizer` с min_df=5, max_df=0.5
# - Токенизация: `custom_new_tokenizer` (стемминг + обновленный список стоп-слов)
# - Классификатор: `LogisticRegression` с penalty='l1', C=2.0, solver='liblinear'
# - Размер словаря: 6 120 токенов
# - Важнейшие признаки каждого класса соответствуют негативной или позитивной окраске
# - Модель сохранена в `'models/logreg_tfidf.pkl'`
#
# **Метрики:**
# - Accuracy на тесте - 88.35%, ROC-AUC на тесте - 0.9473 (намного превосходит случайное угадывание - 0.5)
# - F1-score (0.87–0.91) показывает хороший баланс между Precision и Recall.
# - Метрики сбалансированы между классами, что говорит об отсутствии смещения в пользу одного из них
#
# **Матрица ошибок:**
# - False Negative: модель ошибочно классифицировала 543 позитивных твита как негативные.
# - False Positive: модель ошибочно классифицировала 626 негативных твитов как позитивные.
# - Модель **чаще путает негатив с позитивом**, чем наоборот. Возможная причина — использование иронии и сарказма в твитах, которые трудно распознать без учета контекста, или неоднозначность эмоциональной окраски в тексте.
#
# **Разработанная модель может быть использована для:**
# - Мониторинга общественных настроений в реальном времени.
# - Выявления тревожных тенденций в обсуждении кризисных ситуаций.

# %% [markdown]
# ### Возможные доработки для улучшения работы модели:
# - **Расширение словаря:** текущий словарь в 6120 токенов довольно маленький, поэтому можно использовать предобученные эмбеддинги *(Word2Vec, FastText, BERT)*, чтобы учитывать больше слов и при этом избежать переобучения.
# - **Использование более сложных моделей** вместо логистической регрессии. Современные модели, такие как BERT, способны учитывать контекст и порядок слов, а также работать с разными языками.
# - Мы на практике увидели, что в текстах твитов используются сленг и различные сокращения слов (тот же самый 'da'). Поэтому имеет смысл **улучшить токенизацию для неформального языка** в целом, а не для отдельных токенов. Также можно учитывать эмодзи как признаки тональности
